# %%
# !ls
# Out:
# CRISP_DM.png                   Project_Setup_2_3.ipynb
# Data_Gathering_3_2-Copy1.ipynb Untitled.ipynb
# Data_Gathering_3_2.ipynb       ads_covid-19

# %%
import subprocess
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

# %% [markdown]
# ![CRISP_DM](CRISP_DM.png)

# %% [markdown]
# # Data Understanding

# %% [markdown]
# * RKI, webscrape (webscraping) https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Fallzahlen.html
# * John Hopkins (GITHUB) https://github.com/CSSEGISandData/COVID-19.git
# * REST API services to retreive data https://npgeo-corona-npgeo-de.hub.arcgis.com/

# %%
# %cd ads_covid-19/
# Out:
# /Users/SHS/Desktop/EDS_SS2022_Salim/ads_covid-19

# %% [markdown]
# # Johns Hopkins GITHUB csv data
#
# git clone/pull https://github.com/CSSEGISandData/COVID-19.git
#
# Done in the terminal.

# %%
# %ls
# Out:
# LICENSE              models/              setup.py
# Makefile             notebooks/           src/
# README.md            references/          test_environment.py
# data/                reports/             tox.ini
# docs/                requirements.txt

# %%
git_pull = subprocess.Popen( "/usr/bin/git pull" , 
                     cwd = os.path.dirname( 'data/raw/COVID-19/' ), 
                     shell = True, 
                     stdout = subprocess.PIPE, 
                     stderr = subprocess.PIPE )
(out, error) = git_pull.communicate()


print("Error : " + str(error)) 
print("out : " + str(out))
# Out:
# Error : b'From https://github.com/CSSEGISandData/COVID-19\n   6286b3fbae..8217deb8da  master     -> origin/master\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-05-18-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-05-18-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-05-20-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-05-20-2022\n   04e4ccbb90..9cce76d726  web-data   -> origin/web-data\n'
# ...

# %%
data_path = 'data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw = pd.read_csv(data_path)

# %%
pd_raw
# Out:
#                                    Province/State  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                    Australian Capital Territory
# 10                                New South Wales
# 11                             Northern Territory
# 12                                     Queensland
# 13                                South Australia
# 14                                       Tasmania
# 15                                       Victoria
# 16                              Western Australia
# 17                                            NaN
# ...

# %%
# Display all rows 
pd.set_option('display.max_rows', 500)

# %%
pd_raw
# Out:
#                                    Province/State  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                    Australian Capital Territory
# 10                                New South Wales
# 11                             Northern Territory
# 12                                     Queensland
# 13                                South Australia
# 14                                       Tasmania
# 15                                       Victoria
# 16                              Western Australia
# 17                                            NaN
# ...

# %% [markdown]
# End of data gatering
#
# ====================

# %% [markdown]
# # Webscraping

# %%
page = requests.get("https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Fallzahlen.html")

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup.get_text()
# Out:
# '\n\n\n\n\nRKI  -  Coronavirus SARS-CoV-2 - COVID-19: Fallzahlen in Deutschland und weltweit\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n//<![CDATA[\n      // i18n\n        var PRINT_PAGE_TEXT = \'Seite drucken\';\n        var PRINT_TOOLTIP = \'Artikel drucken (öffnet Dialog)\';\n        var SCALE_IMG = \'Schriftgröße\';\n        var SCALE_IMG_LARGE = \'Schriftgröße vergrößern\';\n        var SCALE_IMG_NORMAL = \'Schriftgröße verkleinern\';\n        var SHOW_MORE = \'mehr anzeigen\';\nwindow.LABEL_MOREDETAILS = \'mehr anzeigen\';\nwindow.LABEL_LESSDETAILS = \'weniger anzeigen\';\n      //]]>\n    \n\n\n\n\n\nNavigation und Service\nSpringe direkt zu:\n\nInhalt\nHauptmenu\nSuche\n\n\n\n\n\n\n\nServicemenü\nKon\xadtaktIn\xadhaltHil\xadfeIm\xadpres\xads\xadumDa\xadten\xadschut\xadz\xader\xadklä\xadrungRSSEnglish\n\n\n\n\nErklärung zur Barrierefreiheit\n\n\nGebärdensprache\n\n\nLeichte Sprache\n\n\n\n\nSuche\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nKontakt\nNavigation\
# ...

# %%
html_table = soup.find('table')

# %%
all_rows = html_table.find_all('tr')

# %%
final_data_list = [] 
for pos, rows in enumerate(all_rows):
    print(pos)
    #print(rows)
    col_list = [each_col.get_text(strip=True) for each_col in rows.find_all('td')] 
    final_data_list.append(col_list)
    print(col_list)
# Out:
# 0
# []
# 1
# []
# 2
# ['Baden-Württem\xadberg', '3.634.699', '5.252', '37.158', '334,7', '16.023']
# 3
# ['Bayern', '4.845.441', '7.554', '53.275', '405,4', '23.943']
# 4
# ['Berlin', '1.037.139', '1.637', '10.334', '282,0', '4.574']
# 5
# ['Branden\xadburg', '785.100', '895', '5.567', '219,9', '5.643']
# 6
# ['Bremen', '197.528', '361', '3.165', '465,4', '772']
# 7
# ['Hamburg', '574.420', '1.389', '6.686', '360,9', '2.637']
# 8
# ['Hessen', '1.829.345', '3.384', '27.491', '436,8', '10.067']
# 9
# ['Meck\xadlenburg-Vor\xadpommern', '482.814', '646', '4.506', '279,7', '2.214']
# 10
# ['Nieder\xadsachsen', '2.322.752', '6.794', '40.556', '506,7', '9.206']
# 11
# ['Nord\xadrhein-West\xadfalen', '5.202.683', '12.408', '64.839', '361,7', '25.244']
# 12
# ['Rhein\xadland-Pfalz', '1.135.573', '2.685', '13.155', '321,0', '5.634']
# 13
# ['Saarland', '312.447', '431', '2.974', '302,2', '1.671']
# 14
# ['Sachsen', '1.500.881', '1.155', '7.365', '181,5', '15.480']
# 15
# ...

# %%
pd.DataFrame(final_data_list).dropna().rename(columns={0:'state', 
                                                      1: 'cases',
                                                      2: 'changes',
                                                      3: 'cases_per_100k',
                                                      4: 'fatal', 
                                                      5: 'comment'})
# Out:
#                        state       cases changes cases_per_100k  fatal  \
# 2         Baden-Württem­berg   3.634.699   5.252         37.158  334,7
# 3                     Bayern   4.845.441   7.554         53.275  405,4
# 4                     Berlin   1.037.139   1.637         10.334  282,0
# 5               Branden­burg     785.100     895          5.567  219,9
# 6                     Bremen     197.528     361          3.165  465,4
# 7                    Hamburg     574.420   1.389          6.686  360,9
# 8                     Hessen   1.829.345   3.384         27.491  436,8
# 9   Meck­lenburg-Vor­pommern     482.814     646          4.506  279,7
# 10            Nieder­sachsen   2.322.752   6.794         40.556  506,7
# 11     Nord­rhein-West­falen   5.202.683  12.408         64.839  361,7
# 12          Rhein­land-Pfalz   1.135.573   2.685         13.155  321,0
# 13                  Saarland     312.447     431          2.974  302,2
# ...

# %%
pd_daily_status=pd.DataFrame(final_data_list).dropna().rename(columns={0:'state',
                                                       1:'cases',
                                                       2:'changes',
                                                       3:'cases_per_100k',
                                                       4:'fatal',
                                                       5:'comment'})

# %%
pd_daily_status.head()
# Out:
#                 state      cases changes cases_per_100k  fatal comment
# 2  Baden-Württem­berg  3.634.699   5.252         37.158  334,7  16.023
# 3              Bayern  4.845.441   7.554         53.275  405,4  23.943
# 4              Berlin  1.037.139   1.637         10.334  282,0   4.574
# 5        Branden­burg    785.100     895          5.567  219,9   5.643
# 6              Bremen    197.528     361          3.165  465,4     772

# %% [markdown]
# End of webscraping
#
# ==================

# %% [markdown]
# # REST API calls

# %%
## data request for Germany
data=requests.get('https://services7.arcgis.com/mOBPykOjAyBO2ZKk/arcgis/rest/services/Coronaf%C3%A4lle_in_den_Bundesl%C3%A4ndern/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

# %%
json_object=json.loads(data.content) 
type(json_object)
# Out:
# dict

# %%
json_object.keys()
# Out:
# dict_keys(['objectIdFieldName', 'uniqueIdField', 'globalIdFieldName', 'geometryProperties', 'geometryType', 'spatialReference', 'fields', 'features'])

# %%
full_list=[]
for pos,each_dict in enumerate (json_object['features'][:]):
    full_list.append(each_dict['attributes'])

# %%
pd_full_list=pd.DataFrame(full_list)

# %%
pd_full_list.head()
# Out:
#    OBJECTID_1 LAN_ew_AGS           LAN_ew_GEN            LAN_ew_BEZ  \
# 0           1         01   Schleswig-Holstein                  Land
# 1           2         02              Hamburg  Freie und Hansestadt
# 2           3         03        Niedersachsen                  Land
# 3           4         04               Bremen      Freie Hansestadt
# 4           5         05  Nordrhein-Westfalen                  Land
#
#    LAN_ew_EWZ  OBJECTID  Fallzahl  Aktualisierung AGS_TXT  \
# 0     2910875        15    720710   1653084000000      01
# 1     1852478         6    575710   1653084000000      02
# 2     8003421         9   2327961   1653084000000      03
# 3      680130         5    197528   1653084000000      04
# 4    17925570        10   5212843   1653084000000      05
#
#                                GlobalID  faelle_100000_EW   Shape__Area  \
# 0  fc5ba936-c95c-432c-8a33-9eb2f30b660f      24759.221883  4.573731e+10
# ...

# %%
pd_full_list.to_csv('/Users/SHS/Desktop/EDS_SS2022_Salim/ads_covid-19/data/raw/NPGEO/GER_state_data.csv',sep=';')

# %%
pd_full_list.shape[0]
# Out:
# 16

# %% [markdown]
# End of REST_API introduction.
#
# =============================

# %% [markdown]
# # API access via REST service, e.g. USA data

# %% [markdown]
# example of a REST conform interface (attention registration mandatory)
#
# www.smartable.ai (Site not available)

# %%
# US for full list
headers = {
    'Cache-Control': 'no-cache',
    'Subscription-Key': '28ee4219700f48718be78b057beb7eb4',
}

response = requests.get('https://api.smartable.ai/coronavirus/stats/US', headers=headers)
print(response)
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1638                     if errno != 0:
# -> 1639                         raise SysCallError(errno, errorcode.get(errno))
#    1640                 raise SysCallError(-1, "Unexpected EOF")
#
# ...

# %% [markdown]
# (Site not available) - as of 19.05.2022

# %% [markdown]
# End of REST service.
#
# ====================

# %% [markdown]
# # Business Understanding
#
# We would like to track Corona VIRUS spread across countries and with personal local information.
#
# The general information is not so relevant and I would like to have a deep dive into local development of the spread.

# %% [markdown]
# ## Goals
#
# 1) We would like to understand the data quality.
#
# 2) Everything should be automated as much as possible.
# Number of clickes required to execute pipeline.
#
#
# ## Constraints
#
# 1) Each notebook should be left clean and ready for execution.

# %% [markdown]
# # GITHUB csv data
#
# git pull done in automatic way.

# %%
git_pull = subprocess.Popen( "/usr/bin/git pull" , 
                     cwd = os.path.dirname( 'data/raw/COVID-19/' ), 
                     shell = True, 
                     stdout = subprocess.PIPE, 
                     stderr = subprocess.PIPE )
(out, error) = git_pull.communicate()


print("Error : " + str(error)) 
print("out : " + str(out))
# Out:
# Error : b''
# out : b'Already up to date.\n'

# %%
data_path = 'data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw = pd.read_csv(data_path)

# %%
pd_raw
# Out:
#                                    Province/State  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                    Australian Capital Territory
# 10                                New South Wales
# 11                             Northern Territory
# 12                                     Queensland
# 13                                South Australia
# 14                                       Tasmania
# 15                                       Victoria
# 16                              Western Australia
# 17                                            NaN
# ...

# %%
# Display all rows 
pd.set_option('display.max_rows', 500)

# %%
pd_raw
# Out:
#                                    Province/State  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                    Australian Capital Territory
# 10                                New South Wales
# 11                             Northern Territory
# 12                                     Queensland
# 13                                South Australia
# 14                                       Tasmania
# 15                                       Victoria
# 16                              Western Australia
# 17                                            NaN
# ...

# %% [markdown]
# End of data gatering (with git pull in automatic way)
#
# ====================
